# %% [markdown]
# # MBTA GTFS Data
#
# This tutorial will guide you through MBTA's official GTFS datasets, which (TODO)

# %% [markdown]
# ## Current GTFS Data
#
# The MBTA website contains a [page on GTFS](https://www.mbta.com/developers/gtfs) for developers and data analysts. The latest GTFS bundle is always at this URL, updated regularly:
#
# https://cdn.mbta.com/MBTA_GTFS.zip
#
# You can find the documentation for the generic GTFS format [here](https://gtfs.org/documentation/schedule/reference/). MBTA provides additional documentation in [this GitHub repo](https://github.com/mbta/gtfs-documentation) to complement the former.

# %% [markdown]
# ## GTFS Tutorial
#
# TODO

# %%
import pandas as pd

# %% [markdown]
# ## Historical GTFS Data
#
# MBTA keeps track of archived GTFS files with historical schedules since 2009. A list of archives is available at this URL: https://cdn.mbta.com/archive/archived_feeds.txt. The official documentation of this table is [here](https://github.com/mbta/gtfs-documentation/blob/master/reference/gtfs-archive.md).
#
# As an illustration:

# %%
GTFS_ARCHIVES_URL = f"https://cdn.mbta.com/archive/archived_feeds.txt"

gtfs_archives = pd.read_csv(GTFS_ARCHIVES_URL)

# %%
gtfs_archives
# Out:
#      feed_start_date  feed_end_date  \
# 0           20251031       20251213
# 1           20251030       20251030
# 2           20251028       20251029
# 3           20251021       20251027
# 4           20251014       20251020
# ..               ...            ...
# 901         20090515       20090528
# 902         20090424       20090514
# 903         20090409       20090423
# 904         20090403       20090408
# 905         20090313       20090402
#
#                                         feed_version  \
# 0    Fall 2025, 2025-11-07T17:47:27+00:00, version D
# 1    Fall 2025, 2025-11-06T20:50:01+00:00, version D
# 2    Fall 2025, 2025-11-04T18:31:23+00:00, version D
# 3    Fall 2025, 2025-10-28T17:02:25+00:00, version D
# 4    Fall 2025, 2025-10-21T21:42:31+00:00, version D
# ..                                               ...
# 901  GTFS file for Google Transit, published 5/15/09
# 902  GTFS file for Google Transit, published 4/24/09
# 903   GTFS file for Google Transit, published 4/9/09
# 904   GTFS file for Google Transit, published 4/3/09
# 905  GTFS file for Google Transit, published 3/13/09
#
#                                      archive_url archive_note
# 0    https://cdn.mbtace.com/archive/20251031.zip          NaN
# 1    https://cdn.mbtace.com/archive/20251030.zip          NaN
# 2    https://cdn.mbtace.com/archive/20251028.zip          NaN
# 3    https://cdn.mbtace.com/archive/20251021.zip          NaN
# 4    https://cdn.mbtace.com/archive/20251014.zip          NaN
# ..                                           ...          ...
# 901  https://cdn.mbtace.com/archive/20090515.zip          NaN
# 902  https://cdn.mbtace.com/archive/20090424.zip          NaN
# 903  https://cdn.mbtace.com/archive/20090409.zip          NaN
# 904  https://cdn.mbtace.com/archive/20090403.zip          NaN
# 905  https://cdn.mbtace.com/archive/20090313.zip          NaN
#
# [906 rows x 5 columns]

# %% [markdown]
# You can use the ``feed_start_date`` and ``feed_end_date`` fields to find the schedule applicable on a given date. The zip file in ``archive_url`` leads to the GTFS bundle.
